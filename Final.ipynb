# %% [markdown]
# <a href="https://colab.research.google.com/github/haliliceylan/tinder-proxy/blob/master/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Mining Final Project**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Upload csv file to the colab 
from google.colab import files 
uploaded = files.upload() sadasdasds
# Out:
#      <input type="file" id="files-147e71c5-0a8c-4265-8604-af85b68fae60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-147e71c5-0a8c-4265-8604-af85b68fae60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Challenger_Ranked_Games.csv to Challenger_Ranked_Games.csv
# Saving GrandMaster_Ranked_Games.csv to GrandMaster_Ranked_Games.csv
# Saving Master_Ranked_Games.csv to Master_Ranked_Games.csv

# %%
# Read csv file
datacsv = pd.read_csv("Challenger_Ranked_Games.csv")
#datacsv
datacsv.head()
#datacsv.tail()
# Out:
#        gameId  gameDuraton  ...  redTotalHeal  redObjectDamageDealt
# 0  4247263043         1323  ...         38711                 60463
# 1  4247155821         1317  ...         24829                 14105
# 2  4243963257          932  ...         12589                 45201
# 3  4241678498         2098  ...         65312                 88202
# 4  4241538868         2344  ...         86431                 64141
#
# [5 rows x 50 columns]

# %%
y = datacsv.temp
X = datacsv.drop('temp', axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-4669a0960035> in <module>()
# ----> 1 y = datacsv.temp
#       2 X = datacsv.drop('temp', axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'temp'
